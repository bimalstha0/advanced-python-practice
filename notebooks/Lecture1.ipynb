# %%
import pandas as pd

# %%
df = pd.read_csv('mtcars.csv')

# %%
df.head()
# Out:
#    Unnamed: 0       vichle_names   mpg  cyl   disp     hp  drat     wt   qsec  \
# 0           0          Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46
# 1           1      Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02
# 2           2         Datsun 710   NaN    4  108.0   93.0  3.85  2.320  18.61
# 3           3     Hornet 4 Drive  21.4    6  258.0    NaN  3.08  3.215  19.44
# 4           4  Hornet Sportabout  18.7    8  360.0  175.0  3.15  3.440  17.02
#
#    v_Shape   am  gear  carb
# 0      0.0  1.0   4.0     4
# 1      0.0  1.0   4.0     4
# 2      1.0  1.0   4.0     1
# 3      1.0  0.0   3.0     1
# 4      0.0  0.0   NaN     2

# %%
df.tail()
# Out:
#     Unnamed: 0    vichle_names   mpg  cyl   disp     hp  drat     wt  qsec  \
# 27          27    Lotus Europa  30.4    4   95.1  113.0  3.77  1.513  16.9
# 28          28  Ford Pantera L  15.8    8  351.0  264.0  4.22  3.170  14.5
# 29          29    Ferrari Dino  19.7    6  145.0  175.0  3.62  2.770  15.5
# 30          30   Maserati Bora  15.0    8  301.0  335.0  3.54  3.570  14.6
# 31          31      Volvo 142E  21.4    4  121.0  109.0  4.11  2.780  18.6
#
#     v_Shape   am  gear  carb
# 27      1.0  1.0   5.0     2
# 28      0.0  1.0   5.0     4
# 29      0.0  1.0   5.0     6
# 30      0.0  1.0   5.0     8
# 31      1.0  1.0   4.0     2

# %%
df.describe()
# Out:
#        Unnamed: 0        mpg        cyl        disp          hp       drat  \
# count   32.000000  30.000000  32.000000   32.000000   31.000000  31.000000
# mean    15.500000  20.076667   6.187500  230.721875  147.870968   3.609032
# std      9.380832   6.196366   1.785922  123.938694   69.363171   0.538766
# min      0.000000  10.400000   4.000000   71.100000   52.000000   2.760000
# 25%      7.750000  15.275000   4.000000  120.825000   96.000000   3.080000
# 50%     15.500000  19.200000   6.000000  196.300000  123.000000   3.700000
# 75%     23.250000  22.475000   8.000000  326.000000  180.000000   3.920000
# max     31.000000  33.900000   8.000000  472.000000  335.000000   4.930000
#
#               wt       qsec    v_Shape         am       gear     carb
# count  32.000000  29.000000  30.000000  28.000000  29.000000  32.0000
# mean    3.217250  17.601379   0.433333   0.428571   3.724138   2.8125
# std     0.978457   1.535459   0.504007   0.503953   0.751026   1.6152
# ...

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'vichle_names',
#  'mpg',
#  'cyl',
#  'disp',
#  'hp',
#  'drat',
#  'wt',
#  'qsec',
#  'v_Shape',
#  'am',
#  'gear',
#  'carb']

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# vichle_names    0
# mpg             2
# cyl             0
# disp            0
# hp              1
# drat            1
# wt              0
# qsec            3
# v_Shape         2
# am              4
# gear            3
# carb            0
# dtype: int64

# %%
df.isnull().mean()
#ratio of missing values to the count
# Out:
# Unnamed: 0      0.00000
# vichle_names    0.00000
# mpg             0.06250
# cyl             0.00000
# disp            0.00000
# hp              0.03125
# drat            0.03125
# wt              0.00000
# qsec            0.09375
# v_Shape         0.06250
# am              0.12500
# gear            0.09375
# carb            0.00000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    32 non-null     int64
#  1   vichle_names  32 non-null     object
#  2   mpg           30 non-null     float64
#  3   cyl           32 non-null     int64
#  4   disp          32 non-null     float64
#  5   hp            31 non-null     float64
#  6   drat          31 non-null     float64
#  7   wt            32 non-null     float64
#  8   qsec          29 non-null     float64
#  9   v_Shape       30 non-null     float64
#  10  am            28 non-null     float64
#  11  gear          29 non-null     float64
#  12  carb          32 non-null     int64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 3.4+ KB

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# vichle_names     object
# mpg             float64
# cyl               int64
# disp            float64
# hp              float64
# drat            float64
# wt              float64
# qsec            float64
# v_Shape         float64
# am              float64
# gear            float64
# carb              int64
# dtype: object

# %%
cat = df.select_dtypes(include=['O'])
num = df.select_dtypes(exclude=['O'])

# if you want the column names instead of df you can use .columns or .columns.to_list()

# %%
cat.head()
# Out:
#         vichle_names
# 0          Mazda RX4
# 1      Mazda RX4 Wag
# 2         Datsun 710
# 3     Hornet 4 Drive
# 4  Hornet Sportabout

# %%
num.head()
# Out:
#    Unnamed: 0   mpg  cyl   disp     hp  drat     wt   qsec  v_Shape   am  \
# 0           0  21.0    6  160.0  110.0  3.90  2.620  16.46      0.0  1.0
# 1           1  21.0    6  160.0  110.0  3.90  2.875  17.02      0.0  1.0
# 2           2   NaN    4  108.0   93.0  3.85  2.320  18.61      1.0  1.0
# 3           3  21.4    6  258.0    NaN  3.08  3.215  19.44      1.0  0.0
# 4           4  18.7    8  360.0  175.0  3.15  3.440  17.02      0.0  0.0
#
#    gear  carb
# 0   4.0     4
# 1   4.0     4
# 2   4.0     1
# 3   3.0     1
# 4   NaN     2

# %%
# num_cols = [col for col in df.columns if col not in cat_cols]

# %%
df.index.name = 'index'

# %%
# df.get_loc()

# %%
print(df.index.name)
# Out:
# index

# %%
df.head()
# Out:
#        Unnamed: 0       vichle_names   mpg  cyl   disp     hp  drat     wt  \
# index
# 0               0          Mazda RX4  21.0    6  160.0  110.0  3.90  2.620
# 1               1      Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875
# 2               2         Datsun 710   NaN    4  108.0   93.0  3.85  2.320
# 3               3     Hornet 4 Drive  21.4    6  258.0    NaN  3.08  3.215
# 4               4  Hornet Sportabout  18.7    8  360.0  175.0  3.15  3.440
#
#         qsec  v_Shape   am  gear  carb
# index
# 0      16.46      0.0  1.0   4.0     4
# 1      17.02      0.0  1.0   4.0     4
# 2      18.61      1.0  1.0   4.0     1
# 3      19.44      1.0  0.0   3.0     1
# 4      17.02      0.0  0.0   NaN     2

# %%
#creating df from a dictionary

dict ={'name' : ['Bimal','Aanal','Jai'],
        'age' : [21,23,24],}
df_dic = pd.DataFrame(dict)

# %%
df_dic
# Out:
#     name  age
# 0  Bimal   21
# 1  Aanal   23
# 2    Jai   24

# %%
df_dic.to_csv('age.csv')

# %%
df_dic.to_json('age.json')

# %%
#creating df from a Json file
df_json = pd.read_json('age.json')

# %%
df_json
# Out:
#     name  age
# 0  Bimal   21
# 1  Aanal   23
# 2    Jai   24

# %%
df_json.to_excel('age.xlsx')

# %%
pip install openpyxl
# Out:
# ...
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/250.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/250.0 kB ? eta -:--:--
#      ------------------ ------------------- 122.9/250.0 kB 1.0 MB/s eta 0:00:01
#      -------------------------------------- 250.0/250.0 kB 1.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
